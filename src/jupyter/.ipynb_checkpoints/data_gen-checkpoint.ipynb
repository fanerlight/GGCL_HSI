# %%
from scipy.io import loadmat
import numpy as np
import pandas as pd
import scipy.io as sio
from sklearn.model_selection import train_test_split
import random
import tifffile as tiff

# %%
data_sign = 'Pavia'
train_num_per_class = 10
data_path_prefix = '../../data'
save_path = '../../data/%s/%s_split.mat' %(data_sign, data_sign)

# %%
import os, sys
from scipy.io import loadmat
import numpy as np
import pandas as pd
import scipy.io as sio
from sklearn.model_selection import train_test_split
import random
import tifffile as tiff


def load_data(data_sign, data_path_prefix):
    if data_sign == "Indian":
        data = sio.loadmat('%s/Indian_pines_corrected.mat' % data_path_prefix)['indian_pines_corrected']
        labels = sio.loadmat('%s/Indian_pines_gt.mat' % data_path_prefix)['indian_pines_gt']
    elif data_sign == "Pavia":
        data = sio.loadmat('%s/PaviaU.mat' % data_path_prefix)['paviaU']
        labels = sio.loadmat('%s/PaviaU_gt.mat' % data_path_prefix)['paviaU_gt'] 
    elif data_sign == "Houston":
        data = sio.loadmat('%s/Houston.mat' % data_path_prefix)['img']
        labels = sio.loadmat('%s/Houston_gt.mat' % data_path_prefix)['Houston_gt']
    elif data_sign == 'Salinas':
        data = sio.loadmat('%s/Salinas_corrected.mat' % data_path_prefix)['salinas_corrected']
        labels = sio.loadmat('%s/Salinas_gt.mat' % data_path_prefix)['salinas_gt']
    return data, labels

def gen(data_sign, train_num_per_class, data_path_prefix, max_percent=0.5):
    data, labels = load_data(data_sign, data_path_prefix)
    h, w, c = data.shape
    class_num = labels.max()
    class2data = {}
    for i in range(h):
        for j in range(w):
            if labels[i,j] > 0:
                if labels[i, j] in class2data:
                    class2data[labels[i,j]].append([i, j])
                else:
                    class2data[labels[i,j]] = [[i,j]]

    TR = np.zeros_like(labels)
    TE = np.zeros_like(labels)
    for cl in range(class_num):
        class_index = cl + 1
        ll = class2data[class_index]
        all_index = list(range(len(ll)))
        real_train_num = train_num_per_class
        if len(all_index) <= train_num_per_class:
            real_train_num = int(len(all_index) * max_percent) 
        select_train_index = set(random.sample(all_index, real_train_num))
        for index in select_train_index:
            item = ll[index]
            TR[item[0], item[1]] = class_index
    TE = labels - TR
    target = {}
    target['TE'] = TE
    target['TR'] = TR
    target['input'] = data
    return target


def run():
    signs = ['Pavia','Salinas']
    data_path_prefix = '../../data'
    train_num_per_class_list = range(10,90,10)
    for data_sign in signs:
        pp = '../../data/%s' % data_sign
        if not os.path.exists(pp):
            os.makedirs(pp)
        for train_num_per_class in train_num_per_class_list:
            for sample in range(1,4):
                save_path = '%s/%s_%d_split%d.mat' %(pp, data_sign, train_num_per_class,sample)
                target = gen(data_sign, train_num_per_class, data_path_prefix)
                sio.savemat(save_path, target)
                print('save %s done.' % save_path)



if __name__ == "__main__":
    run()
# Out:
# save ../../data/Indian/Indian_10_split1.mat done.
# save ../../data/Indian/Indian_10_split2.mat done.
# save ../../data/Indian/Indian_10_split3.mat done.
# save ../../data/Indian/Indian_60_split1.mat done.
# save ../../data/Indian/Indian_60_split2.mat done.
# save ../../data/Indian/Indian_60_split3.mat done.
# save ../../data/Indian/Indian_70_split1.mat done.
# save ../../data/Indian/Indian_70_split2.mat done.
# save ../../data/Indian/Indian_70_split3.mat done.
# save ../../data/Indian/Indian_80_split1.mat done.
# save ../../data/Indian/Indian_80_split2.mat done.
# save ../../data/Indian/Indian_80_split3.mat done.
# save ../../data/Houston/Houston_10_split1.mat done.
# save ../../data/Houston/Houston_10_split2.mat done.
# save ../../data/Houston/Houston_10_split3.mat done.
# save ../../data/Houston/Houston_60_split1.mat done.
# save ../../data/Houston/Houston_60_split2.mat done.
# save ../../data/Houston/Houston_60_split3.mat done.
# save ../../data/Houston/Houston_70_split1.mat done.
# save ../../data/Houston/Houston_70_split2.mat done.
# save ../../data/Houston/Houston_70_split3.mat done.
# save ../../data/Houston/Houston_80_split1.mat done.
# save ../../data/Houston/Houston_80_split2.mat done.
# save ../../data/Houston/Houston_80_split3.mat done.
# save ../../data/Salinas/Salinas_10_split1.mat done.
# save ../../data/Salinas/Salinas_10_split2.mat done.
# save ../../data/Salinas/Salinas_10_split3.mat done.
# save ../../data/Salinas/Salinas_60_split1.mat done.
# save ../../data/Salinas/Salinas_60_split2.mat done.
# save ../../data/Salinas/Salinas_60_split3.mat done.
# save ../../data/Salinas/Salinas_70_split1.mat done.
# save ../../data/Salinas/Salinas_70_split2.mat done.
# save ../../data/Salinas/Salinas_70_split3.mat done.
# save ../../data/Salinas/Salinas_80_split1.mat done.
# save ../../data/Salinas/Salinas_80_split2.mat done.
# save ../../data/Salinas/Salinas_80_split3.mat done.
